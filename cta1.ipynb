# %%
import pandas as pd
import numpy as np

# %%
cta_data=pd.read_csv("cta1.csv")
cta,keyw = [],[]
for x in range(len(cta_data)):
    cta.append(cta_data['Sentence'][x])
    keyw.append(cta_data['Phrase1'][x])
for x in range(len(cta_data)):
    cta.append(cta_data['Sentence'][x])
    keyw.append(cta_data['Phrase2'][x])
cta,keyw
# Out:
# (['Click here to find out how we did it',
#   'Click here to read our FAQ\xa0',
#   'Try it free now',
#   'Start your free trial now',
#   'Sign up for your free trial immediately',
#   'Your free trial is just a click away',
#   '\xa0Join now and get…',
#   'Start now to get…',
#   '\xa0Talk to an expert now',
#   '\xa0Order now while there’s still time',
#   'Place your order now while everything is still in front of you',
#   '\xa0Send in your application today',
#   'We’re waiting for your call',
#   '\xa0Click here to use this convenient coupon today',
#   'For more details, call…',
#   '\xa0Please don’t hesitate to call us',
#   'Why not give us a call to find out all the details?',
#   'Call us this week to schedule an appointment',
#   'Offer expires very soon',
#   'For a short time only',
#   'Order now and receive a free gift',
#   'Get yours for free now',
#   'Request your FREE quote today',
#   'Click here to find out how we did it',
# ...
